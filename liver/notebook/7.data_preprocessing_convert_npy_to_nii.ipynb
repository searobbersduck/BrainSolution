# %%
import os
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from collections import  Counter
import SimpleITK as sitk
import nibabel as nib
import time
from collections import Counter

# %%
infile = '../data/processed_liver_liver/scalex1_liver/3Dircadb1.10_volume.npy'
volume_data = None
volume_data = np.load(infile)
# volume_data = np.array(volume_data, np.uint8)
print(np.max(volume_data))
print(volume_data.dtype)
mask_img = nib.Nifti1Image(volume_data, affine=np.eye(4))
nib.save(mask_img, '/home/zhangwd/code/work/BrainSolution/tube_seg/task/test.nii.gz')
# Out:
# 1625
# int16

# %%
infile = '../data/processed_liver_liver/scalex1_liver/3Dircadb1.10_volume.nii.gz'
volume_data1 = sitk.ReadImage(infile)
ori_volume_data1 = sitk.GetArrayFromImage(volume_data1)
print(ori_volume_data1.max())

np.save('/home/zhangwd/code/work/BrainSolution/tube_seg/task/test21.npy', ori_volume_data1)

ori_volume_data = np.load('/home/zhangwd/code/work/BrainSolution/tube_seg/task/test21.npy')

mask_img = nib.Nifti1Image(ori_volume_data, affine=np.eye(4))
nib.save(mask_img, '/home/zhangwd/code/work/BrainSolution/tube_seg/task/test21.nii.gz')
# Out:
# 1625

# %%
infile = '/home/zhangwd/code/work/BrainSolution/tube_seg/task/test2.npy'
volume_data = None
volume_data = np.load(infile)
# volume_data = np.array(volume_data, np.uint8)
print(np.max(volume_data))
print(volume_data.dtype)
mask_img = nib.Nifti1Image(volume_data, affine=np.eye(4))
nib.save(mask_img, '/home/zhangwd/code/work/BrainSolution/tube_seg/task/test1.nii.gz')
# Out:
# 1625
# int16

# %%
infile = '/ssd2/zhangwd/code/work/BrainSolution/liver/data/processed_liver_liver/scalex1_liver/3Dircadb1.9_volume.npy'
volume_data = None
volume_data = np.load(infile)
# volume_data = np.array(volume_data, np.uint8)
print(np.max(volume_data))
print(volume_data.dtype)
mask_img = nib.Nifti1Image(volume_data, affine=np.eye(4))
nib.save(mask_img, '/home/zhangwd/code/work/BrainSolution/tube_seg/task/test36.nii.gz')
# Out:
# 1043
# int16

# %%
from glob import glob
infiles = glob('/ssd2/zhangwd/code/work/BrainSolution/liver/data/processed_liver_liver/scalex1_liver/3Dircadb1.*_volume.npy')
for i,infile in enumerate(infiles):
    volume_data = None
    volume_data = np.load(infile)
    # volume_data = np.array(volume_data, np.uint8)
    print(np.max(volume_data))
    print(volume_data.dtype)
    mask_img = nib.Nifti1Image(volume_data, affine=np.eye(4))
    nib.save(mask_img, '/home/zhangwd/code/work/BrainSolution/tube_seg/task/test_{}.nii.gz'.format(i))
# Out:
# 1024
# int16
# 1023
# int16
# 1043
# int16
# 1024
# int16
# 1023
# int16
# 3071
# int16
# 1023
# int16
# 1023
# int16
# 1023
# int16
# 1023
# int16
# 1023
# int16
# 1023
# int16
# 1625
# int16
# 1023
# int16
# 3117
# int16
# 1023
# int16
# 1023
# int16
# 1023
# int16
# 1023
# int16
# 1504
# int16
