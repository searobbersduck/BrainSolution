# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
infile = './label_submission_new.csv'
df = pd.read_csv(infile)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'seriesInstanceUID', 'studyInstanceUID', 'info',
#        'brief_info', 'more_brief_info'],
#       dtype='object')

# %%
series_list = []
for index, row in df.iterrows():
    series_list.append(row['seriesInstanceUID'])

# %%
len(series_list)
# Out:
# 861

# %%
with open(infile.replace('.csv','.txt'), 'w') as f:
    f.write('\n'.join(series_list))
