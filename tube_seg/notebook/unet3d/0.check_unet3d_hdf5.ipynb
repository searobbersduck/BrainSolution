# %%
import h5py
import numpy as np

# %%
f = h5py.File('../../external_lib/pytorch-3dunet/resources/random3D.h5','r')
for key in f.keys():
    print(f[key].name)
    print(f[key].shape)
    print(f[key].dtype)
    print(np.max(f[key]))
    print(np.min(f[key]))
# Out:
# /label
# (128, 128, 128)
# int64
# 1
# 0
# /random
# (128, 128, 128)
# float64
# 0.9999999219188012
# 2.630145274906681e-07
# /raw
# (128, 128, 128)
# float64
# 0.9999998182724674
# 8.079959101792156e-08
