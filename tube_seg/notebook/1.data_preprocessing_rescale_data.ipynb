# %% [markdown]
# ## resize mask
# 1. 对mask进行resize，观察在不同比例resize下，mask的显示效果
# 2. 在对mask进行resize之前，先见mask预处理成统一的格式（比如标签值统一为1或255）
#
# ## 数据存储说明
# 1. 输出路径存储在：`../data/brain_henan/algo_mask/brain_seg_by_threshold_preprocessed`
# 2. 数据格式以series_uid+后缀的形式存储
#     * series_uid + _mix, 代表混合电压的数据
#         * 如`1.3.12.2.1107.5.99.2.9594.30000017032111384964000000240_mix.nii.gz`代表混合电压原始体数据，存储格式为nii.gz
#         * 如`1.3.12.2.1107.5.99.2.9594.30000017032111384964000000240_mix.npy`代表混合电压原始体数据，存储格式为npy
#         * 如`1.3.12.2.1107.5.99.2.9594.30000017032111384964000000240_mix_[0-1].npy`, 代表混合电压数据归一化到[0,1]范围内，存储格式为npy
#         * 如`1.3.12.2.1107.5.99.2.9594.30000017032111384964000000240_mix_[-1-1].npy`, 代表混合电压数据归一化到[-1,1]范围内，存储格式为npy
#     * series_uid + _mix, 代表减影数据
#         * 如`1.3.12.2.1107.5.99.2.9594.30000017032111384964000000240_substraction.nii.gz`代表减影原始体数据，存储格式为nii.gz
#         * 如`1.3.12.2.1107.5.99.2.9594.30000017032111384964000000240_substraction.npy`代表减影原始体数据，存储格式为npy
#         * 如`1.3.12.2.1107.5.99.2.9594.30000017032111384964000000240_substraction_[0-1].npy`, 代表减影数据归一化到[0,1]范围内，存储格式为npy
#         * 如`1.3.12.2.1107.5.99.2.9594.30000017032111384964000000240_substraction_[-1-1].npy`, 代表减影数据归一化到[-1,1]范围内，存储格式为npy
#     * series_uid + _mask, 代表减影数据的mask，也与原始数据对应
#         * 如`1.3.12.2.1107.5.99.2.9594.30000017032111384964000000240_mask.nii.gz`代表减影原始体数据，存储格式为nii.gz,数据格式uin8
#         * 如`1.3.12.2.1107.5.99.2.9594.30000017032111384964000000240_mask.npy`代表减影原始体数据，存储格式为npy, 数据格式uint8

# %%
import os
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from collections import  Counter
import SimpleITK as sitk
import nibabel as nib
import time
from tqdm import tqdm

# %%
def sitk_new_blank_image(size, spacing, direction, origin, default_value=0.):
    image = sitk.GetImageFromArray(np.ones(size, dtype=np.float).T * default_value)
    image.SetSpacing(spacing)
    image.SetDirection(direction)
    image.SetOrigin(origin)
    return image

def sitk_resample_to_image(image, reference_image, interpolator, default_value=0., transform=None,
                           output_pixel_type=None):
    if transform is None:
        transform = sitk.Transform()
        transform.SetIdentity()
    if output_pixel_type is None:
        output_pixel_type = image.GetPixelID()
    resample_filter = sitk.ResampleImageFilter()
    resample_filter.SetInterpolator(interpolator)
    resample_filter.SetTransform(transform)
    resample_filter.SetOutputPixelType(output_pixel_type)
    resample_filter.SetDefaultPixelValue(default_value)
    resample_filter.SetReferenceImage(reference_image)
    return resample_filter.Execute(image)

def generate_data_propotional(series_uid, scale, interpolator, output_pixel_type, is_dcm=True):
    if is_dcm:
        reader = sitk.ImageSeriesReader()
        filenames = reader.GetGDCMSeriesFileNames(series_uid)
        reader.SetFileNames(filenames)
        im = reader.Execute()
    else:
        im = sitk.ReadImage(series_uid)
    ori_spacing = im.GetSpacing()
    ori_size = im.GetSize()
    new_size = [0,0,0]
    for i in range(3):
        new_size[i] = int(ori_spacing[i]*ori_size[i]/(ori_spacing[0]))
    new_spacing = [ori_spacing[0]]*3

#     interpolator = sitk.sitkNearestNeighbor

    black_im = sitk_new_blank_image(new_size, new_spacing, im.GetDirection(), im.GetOrigin())
    new_im = sitk_resample_to_image(im, black_im, interpolator, default_value=0, output_pixel_type=output_pixel_type)

    return new_im

# %% [markdown]
# 1. 找到减影数据的源数据和分割结果数据
# 2. 找到减影数据对应的混合电压、高电压、低电压数据
# 3. 存储在：
#     ```
#     substraction_data_list = []
#     mix_data_list = []
#     mask_list = []
#     ```

# %%
src_root = '../data/brain_henan/bystudy'
all_data_file = '../data/brain_henan/algo_mask/brain_seg_by_threshold/out.csv'
mask_root = '../data/brain_henan/algo_mask/brain_seg_by_threshold'
outdir = '../data/brain_henan/algo_mask/brain_seg_by_threshold_preprocessed'
os.makedirs(outdir, exist_ok=True)
df_data_table = pd.read_csv(all_data_file)

substraction_data_list = []
mix_data_list = []
mask_list = []


for index, row in df_data_table.iterrows():
    mask_file = os.path.join(mask_root, row['剪影'])
    if not os.path.isdir(mask_file):
        continue
    mask_file = os.path.join(mask_file, 'mask_demo0.mha')
    if not os.path.isfile(mask_file):
        continue
    substraction_data_file = os.path.join(src_root, row['study_uid'], row['剪影'])
    if not os.path.isdir(substraction_data_file):
        continue
    mix_data_file = os.path.join(src_root, row['study_uid'], row['mix'])
    if not os.path.isdir(mix_data_file):
        continue
    mask_list.append(mask_file)
    substraction_data_list.append(substraction_data_file)
    mix_data_list.append(mix_data_file)

# %%
# infile = mix_data_list[0]
# mix_data = generate_data_propotional(infile, None, sitk.sitkLinear, sitk.sitkInt16)
# substraction_data = generate_data_propotional(substraction_data_list[0], None, sitk.sitkLinear, sitk.sitkInt16)
# mask = generate_data_propotional(mask_list[0], None, sitk.sitkNearestNeighbor, sitk.sitkUInt8, False)


# print(mix_data.GetSize())
# print(substraction_data.GetSize())
# print(mask.GetSize())

# %%
for i in range(len(mask_list)):
    beg = time.time()
    print('====> begin to process {}'.format(mask_list[i]))
    mix_data = generate_data_propotional(mix_data_list[i], None, sitk.sitkLinear, sitk.sitkInt16)
    substraction_data = generate_data_propotional(substraction_data_list[i], None, sitk.sitkLinear, sitk.sitkInt16)
    mask = generate_data_propotional(mask_list[i], None, sitk.sitkNearestNeighbor, sitk.sitkUInt8, False)
    print('\ttime elpased when rescale data:{:.3f}'.format(time.time()-beg))
    
    
    # save to nii.gz
    basename = os.path.basename(substraction_data_list[i])
    out_name_mix = os.path.join(outdir, '{}_mix.nii.gz'.format(basename))
    out_name_substraction = os.path.join(outdir, '{}_substraction.nii.gz'.format(basename))
    out_name_mask = os.path.join(outdir, '{}_mask.nii.gz'.format(basename))
    
    sitk.WriteImage(mix_data, out_name_mix)
    sitk.WriteImage(substraction_data, out_name_substraction)
    sitk.WriteImage(mask, out_name_mask)
    print('\ttime elpased when save to nii:{:.3f}'.format(time.time()-beg))
    
    
    # save to npy
    out_name_mix_npy = os.path.join(outdir, '{}_mix.npy'.format(basename))
    out_name_substraction_npy = os.path.join(outdir, '{}_substraction.npy'.format(basename))
    out_name_mask_npy = os.path.join(outdir, '{}_mask.npy'.format(basename))
    
    ori_mix_data = sitk.GetArrayFromImage(mix_data)
    ori_substraction_data = sitk.GetArrayFromImage(substraction_data)
    ori_mask = sitk.GetArrayFromImage(mask)
    
    ori_mask[ori_mask == 7] = 1
    
#     with open(out_name_mix_npy, 'wb') as f:
#         np.save(f, ori_mix_data)
#     with open(out_name_substraction_npy, 'wb') as f:
#         np.save(f, ori_substraction_data)
#     with open(out_name_mask_npy, 'wb') as f:
#         np.save(f, ori_mask)
    np.save(out_name_mix_npy, ori_mix_data)
    np.save(out_name_substraction_npy, ori_substraction_data)
    np.save(out_name_mask_npy, ori_mask)
    
    print('\ttime elpased when save npy:{:.3f}'.format(time.time()-beg))
            
    # calculate min/max
    mix_min = np.min(ori_mix_data)
    mix_max = np.max(ori_mix_data)
    
    substraction_min = np.min(ori_substraction_data)
    substraction_max = np.max(ori_substraction_data)
    
    print('\ttime elpased when calculate min&max:{:.3f}'.format(time.time()-beg))
    
    # normalize volume data to [0,1] and save float to npy
    out_name_mix_npy = os.path.join(outdir, '{}_mix_[0-1].npy'.format(basename))
    out_name_substraction_npy = os.path.join(outdir, '{}_substraction_[0-1].npy'.format(basename))
    
    ori_mix_data_0_1 = (ori_mix_data-mix_min)/(mix_max-mix_min)
    ori_substraction_data_0_1 = (ori_substraction_data-substraction_min)/(substraction_max-substraction_min)
    
#     with open(out_name_mix_npy, 'wb') as f:
#         np.save(f, ori_mix_data_0_1)
#     with open(out_name_substraction_npy, 'wb') as f:
#         np.save(f, ori_substraction_data_0_1)
    np.save(out_name_mix_npy, ori_mix_data_0_1)
    np.save(out_name_substraction_npy, ori_substraction_data_0_1)
        
    print('\ttime elpased when save normalize [0,1] npy:{:.3f}'.format(time.time()-beg))
    
    
    # normalize volume data to [0,1] and save float to npy
    out_name_mix_npy = os.path.join(outdir, '{}_mix_[-1-1].npy'.format(basename))
    out_name_substraction_npy = os.path.join(outdir, '{}_substraction_[-1-1].npy'.format(basename))
    
    tmp_v = mix_max+mix_min
    ori_mix_data_0_1 = (ori_mix_data*2-tmp_v)/tmp_v
    tmp_v = substraction_max+substraction_min
    ori_substraction_data_0_1 = (ori_substraction_data*2-tmp_v)/tmp_v
    
#     with open(out_name_mix_npy, 'wb') as f:
#         np.save(f, ori_mix_data_0_1)
#     with open(out_name_substraction_npy, 'wb') as f:
#         np.save(f, ori_substraction_data_0_1)
    np.save(out_name_mix_npy, ori_mix_data_0_1)
    np.save(out_name_substraction_npy, ori_substraction_data_0_1)
        
    print('\ttime elpased when save normalize [-1,1] npy:{:.3f}'.format(time.time()-beg))
    
    
    print('====> end to process {}, Time Elapsed:{:.3f}s\n'.format(mask_list[i], time.time()-beg))
# Out:
# ====> begin to process ../data/brain_henan/algo_mask/brain_seg_by_threshold/1.3.12.2.1107.5.99.2.9594.30000017032111384964000000240/mask_demo0.mha
# 	time elpased when rescale data:203.988
# 	time elpased when save to nii:260.309
# 	time elpased when save npy:270.761
# 	time elpased when calculate min&max:271.238
# 	time elpased when save normalize [0,1] npy:298.758
# 	time elpased when save normalize [-1,1] npy:308.548
# ====> end to process ../data/brain_henan/algo_mask/brain_seg_by_threshold/1.3.12.2.1107.5.99.2.9594.30000017032111384964000000240/mask_demo0.mha, Time Elapsed:308.548s
#
# ====> begin to process ../data/brain_henan/algo_mask/brain_seg_by_threshold/1.3.12.2.1107.5.99.2.9594.30000018101817420531200000128/mask_demo0.mha
# 	time elpased when rescale data:192.455
# 	time elpased when save to nii:253.593
# 	time elpased when save npy:271.640
# 	time elpased when calculate min&max:272.233
# 	time elpased when save normalize [0,1] npy:340.174
# 	time elpased when save normalize [-1,1] npy:388.460
# ====> end to process ../data/brain_henan/algo_mask/brain_seg_by_threshold/1.3.12.2.1107.5.99.2.9594.30000018101817420531200000128/mask_demo0.mha, Time Elapsed:388.461s
#
# ====> begin to process ../data/brain_henan/algo_mask/brain_seg_by_threshold/1.3.12.2.1107.5.99.2.9594.30000016040823144126500004946/mask_demo0.mha
# 	time elpased when rescale data:189.666
# 	time elpased when save to nii:237.782
# 	time elpased when save npy:251.098
# 	time elpased when calculate min&max:251.493
# 	time elpased when save normalize [0,1] npy:289.395
# 	time elpased when save normalize [-1,1] npy:317.222
# ====> end to process ../data/brain_henan/algo_mask/brain_seg_by_threshold/1.3.12.2.1107.5.99.2.9594.30000016040823144126500004946/mask_demo0.mha, Time Elapsed:317.223s
#
# ====> begin to process ../data/brain_henan/algo_mask/brain_seg_by_threshold/1.3.12.2.1107.5.99.2.9594.30000019042916441620300004106/mask_demo0.mha
# 	time elpased when rescale data:258.816
# 	time elpased when save to nii:324.898
# 	time elpased when save npy:340.654
# 	time elpased when calculate min&max:341.285
# 	time elpased when save normalize [0,1] npy:402.025
# 	time elpased when save normalize [-1,1] npy:449.500
# ====> end to process ../data/brain_henan/algo_mask/brain_seg_by_threshold/1.3.12.2.1107.5.99.2.9594.30000019042916441620300004106/mask_demo0.mha, Time Elapsed:449.500s
#
# ====> begin to process ../data/brain_henan/algo_mask/brain_seg_by_threshold/1.3.12.2.1107.5.99.2.9594.30000019033013292326500013126/mask_demo0.mha
# 	time elpased when rescale data:303.543
# 	time elpased when save to nii:383.308
# 	time elpased when save npy:400.721
# 	time elpased when calculate min&max:401.449
# 	time elpased when save normalize [0,1] npy:460.032
# 	time elpased when save normalize [-1,1] npy:526.041
# ====> end to process ../data/brain_henan/algo_mask/brain_seg_by_threshold/1.3.12.2.1107.5.99.2.9594.30000019033013292326500013126/mask_demo0.mha, Time Elapsed:526.042s
#
# ====> begin to process ../data/brain_henan/algo_mask/brain_seg_by_threshold/1.3.12.2.1107.5.99.2.9594.30000016042715412376500000294/mask_demo0.mha
# 	time elpased when rescale data:252.240
# 	time elpased when save to nii:333.045
# 	time elpased when save npy:359.021
# 	time elpased when calculate min&max:359.854
# 	time elpased when save normalize [0,1] npy:442.587
# 	time elpased when save normalize [-1,1] npy:508.512
# ====> end to process ../data/brain_henan/algo_mask/brain_seg_by_threshold/1.3.12.2.1107.5.99.2.9594.30000016042715412376500000294/mask_demo0.mha, Time Elapsed:508.512s
#
# ====> begin to process ../data/brain_henan/algo_mask/brain_seg_by_threshold/1.3.12.2.1107.5.99.2.9594.30000016101812415384300003147/mask_demo0.mha
# 	time elpased when rescale data:252.219
# 	time elpased when save normalize [0,1] npy:352.158
# 	time elpased when save normalize [-1,1] npy:390.325
# ====> end to process ../data/brain_henan/algo_mask/brain_seg_by_threshold/1.3.12.2.1107.5.99.2.9594.30000016101812415384300003147/mask_demo0.mha, Time Elapsed:390.325s
#
# ====> begin to process ../data/brain_henan/algo_mask/brain_seg_by_threshold/1.3.12.2.1107.5.99.2.9594.30000019012215113151500007098/mask_demo0.mha
# 	time elpased when rescale data:254.164
# 	time elpased when save to nii:322.937
# 	time elpased when save npy:333.133
# 	time elpased when calculate min&max:333.868
# 	time elpased when save normalize [0,1] npy:380.974
# 	time elpased when save normalize [-1,1] npy:425.029
# ====> end to process ../data/brain_henan/algo_mask/brain_seg_by_threshold/1.3.12.2.1107.5.99.2.9594.30000019012215113151500007098/mask_demo0.mha, Time Elapsed:425.029s
#
# ====> begin to process ../data/brain_henan/algo_mask/brain_seg_by_threshold/1.3.12.2.1107.5.99.2.9594.30000019041407443398400023224/mask_demo0.mha
# 	time elpased when rescale data:334.075
# 	time elpased when save to nii:420.731
# 	time elpased when save npy:435.370
# 	time elpased when calculate min&max:436.277
# 	time elpased when save normalize [0,1] npy:472.060
# 	time elpased when save normalize [-1,1] npy:508.655
# ====> end to process ../data/brain_henan/algo_mask/brain_seg_by_threshold/1.3.12.2.1107.5.99.2.9594.30000019041407443398400023224/mask_demo0.mha, Time Elapsed:508.656s
#
# ====> begin to process ../data/brain_henan/algo_mask/brain_seg_by_threshold/1.3.12.2.1107.5.99.2.9594.30000019051714472243700015866/mask_demo0.mha
# 	time elpased when rescale data:208.935
# 	time elpased when save to nii:274.463
# 	time elpased when save npy:287.672
# 	time elpased when calculate min&max:288.309
# 	time elpased when save normalize [0,1] npy:328.563
# 	time elpased when save normalize [-1,1] npy:365.114
# ====> end to process ../data/brain_henan/algo_mask/brain_seg_by_threshold/1.3.12.2.1107.5.99.2.9594.30000019051714472243700015866/mask_demo0.mha, Time Elapsed:365.115s
#
# ====> begin to process ../data/brain_henan/algo_mask/brain_seg_by_threshold/1.3.12.2.1107.5.99.2.9594.30000019032607484885900011345/mask_demo0.mha
# 	time elpased when rescale data:197.208
# 	time elpased when save to nii:262.393
# 	time elpased when save npy:269.007
# 	time elpased when calculate min&max:269.557
# 	time elpased when save normalize [0,1] npy:304.460
# 	time elpased when save normalize [-1,1] npy:338.863
# ====> end to process ../data/brain_henan/algo_mask/brain_seg_by_threshold/1.3.12.2.1107.5.99.2.9594.30000019032607484885900011345/mask_demo0.mha, Time Elapsed:338.863s
#
# ====> begin to process ../data/brain_henan/algo_mask/brain_seg_by_threshold/1.3.12.2.1107.5.99.2.9594.30000018113015131734300000214/mask_demo0.mha
# 	time elpased when rescale data:175.692
# 	time elpased when save to nii:257.407
# 	time elpased when save npy:268.343
# 	time elpased when calculate min&max:269.207
# 	time elpased when save normalize [0,1] npy:299.628
# 	time elpased when save normalize [-1,1] npy:340.828
# ====> end to process ../data/brain_henan/algo_mask/brain_seg_by_threshold/1.3.12.2.1107.5.99.2.9594.30000018113015131734300000214/mask_demo0.mha, Time Elapsed:340.828s
#
# ====> begin to process ../data/brain_henan/algo_mask/brain_seg_by_threshold/1.3.12.2.1107.5.99.2.9594.30000019033013292326500020192/mask_demo0.mha
# 	time elpased when rescale data:185.065
# 	time elpased when save to nii:245.964
# 	time elpased when save npy:255.268
# 	time elpased when calculate min&max:255.798
# 	time elpased when save normalize [0,1] npy:296.931
# 	time elpased when save normalize [-1,1] npy:339.589
# ====> end to process ../data/brain_henan/algo_mask/brain_seg_by_threshold/1.3.12.2.1107.5.99.2.9594.30000019033013292326500020192/mask_demo0.mha, Time Elapsed:339.589s
#
# ====> begin to process ../data/brain_henan/algo_mask/brain_seg_by_threshold/1.3.12.2.1107.5.99.2.9594.30000019051714472243700000128/mask_demo0.mha
# 	time elpased when rescale data:292.711
# 	time elpased when save to nii:367.420
# 	time elpased when save npy:380.959
# 	time elpased when calculate min&max:381.680
# 	time elpased when save normalize [0,1] npy:429.613
# 	time elpased when save normalize [-1,1] npy:487.749
# ====> end to process ../data/brain_henan/algo_mask/brain_seg_by_threshold/1.3.12.2.1107.5.99.2.9594.30000019051714472243700000128/mask_demo0.mha, Time Elapsed:487.749s
#
# ====> begin to process ../data/brain_henan/algo_mask/brain_seg_by_threshold/1.3.12.2.1107.5.99.2.9594.30000016090613565907800006391/mask_demo0.mha
# 	time elpased when rescale data:218.151
# 	time elpased when save to nii:272.945
# 	time elpased when save npy:284.856
# 	time elpased when calculate min&max:285.343
# 	time elpased when save normalize [0,1] npy:328.311
# 	time elpased when save normalize [-1,1] npy:363.816
# ====> end to process ../data/brain_henan/algo_mask/brain_seg_by_threshold/1.3.12.2.1107.5.99.2.9594.30000016090613565907800006391/mask_demo0.mha, Time Elapsed:363.817s
#
# ====> begin to process ../data/brain_henan/algo_mask/brain_seg_by_threshold/1.3.12.2.1107.5.99.2.9594.30000019030716410834300001344/mask_demo0.mha
# 	time elpased when rescale data:190.430
# 	time elpased when save to nii:252.058
# 	time elpased when save npy:266.577
# 	time elpased when calculate min&max:267.118
# 	time elpased when save normalize [0,1] npy:303.609
# 	time elpased when save normalize [-1,1] npy:338.260
# ====> end to process ../data/brain_henan/algo_mask/brain_seg_by_threshold/1.3.12.2.1107.5.99.2.9594.30000019030716410834300001344/mask_demo0.mha, Time Elapsed:338.260s
#
# ====> begin to process ../data/brain_henan/algo_mask/brain_seg_by_threshold/1.3.12.2.1107.5.99.2.9594.30000018091512264239000002517/mask_demo0.mha
# 	time elpased when rescale data:169.074
# 	time elpased when save to nii:223.629
# 	time elpased when save npy:232.738
# 	time elpased when calculate min&max:233.236
# 	time elpased when save normalize [0,1] npy:264.735
# 	time elpased when save normalize [-1,1] npy:301.916
# ====> end to process ../data/brain_henan/algo_mask/brain_seg_by_threshold/1.3.12.2.1107.5.99.2.9594.30000018091512264239000002517/mask_demo0.mha, Time Elapsed:301.916s
#
# ====> begin to process ../data/brain_henan/algo_mask/brain_seg_by_threshold/1.3.12.2.1107.5.99.2.9594.30000018031913250528100001457/mask_demo0.mha
# 	time elpased when rescale data:269.683
# 	time elpased when save to nii:327.213
# 	time elpased when save npy:337.737
# 	time elpased when calculate min&max:338.238
# 	time elpased when save normalize [0,1] npy:375.415
# 	time elpased when save normalize [-1,1] npy:409.832
# ====> end to process ../data/brain_henan/algo_mask/brain_seg_by_threshold/1.3.12.2.1107.5.99.2.9594.30000018031913250528100001457/mask_demo0.mha, Time Elapsed:409.833s
#
# ====> begin to process ../data/brain_henan/algo_mask/brain_seg_by_threshold/1.3.12.2.1107.5.99.2.9594.30000016010904522334300001290/mask_demo0.mha
# 	time elpased when rescale data:169.214
# 	time elpased when save to nii:237.949
# 	time elpased when save npy:251.773
# 	time elpased when calculate min&max:252.460
# 	time elpased when save normalize [0,1] npy:308.754
# 	time elpased when save normalize [-1,1] npy:340.657
# ====> end to process ../data/brain_henan/algo_mask/brain_seg_by_threshold/1.3.12.2.1107.5.99.2.9594.30000016010904522334300001290/mask_demo0.mha, Time Elapsed:340.657s
#
# ====> begin to process ../data/brain_henan/algo_mask/brain_seg_by_threshold/1.3.12.2.1107.5.99.2.9594.30000017051013402768700000128/mask_demo0.mha
# 	time elpased when rescale data:226.601
# 	time elpased when save to nii:283.255
# 	time elpased when save npy:299.022
# 	time elpased when calculate min&max:299.660
# 	time elpased when save normalize [0,1] npy:324.176
# 	time elpased when save normalize [-1,1] npy:352.132
# ====> end to process ../data/brain_henan/algo_mask/brain_seg_by_threshold/1.3.12.2.1107.5.99.2.9594.30000017051013402768700000128/mask_demo0.mha, Time Elapsed:352.133s
#
# ====> begin to process ../data/brain_henan/algo_mask/brain_seg_by_threshold/1.3.12.2.1107.5.99.2.9594.30000019042616245185900000128/mask_demo0.mha
# 	time elpased when rescale data:175.116
# 	time elpased when save to nii:242.046
# 	time elpased when save npy:249.510
# 	time elpased when calculate min&max:250.112
# 	time elpased when save normalize [0,1] npy:275.735
# 	time elpased when save normalize [-1,1] npy:297.507
# ====> end to process ../data/brain_henan/algo_mask/brain_seg_by_threshold/1.3.12.2.1107.5.99.2.9594.30000019042616245185900000128/mask_demo0.mha, Time Elapsed:297.508s
#
# ====> begin to process ../data/brain_henan/algo_mask/brain_seg_by_threshold/1.3.12.2.1107.5.99.2.9594.30000019041407443398400000128/mask_demo0.mha
# 	time elpased when rescale data:304.003
# 	time elpased when save to nii:375.817
# 	time elpased when save npy:390.474
# 	time elpased when calculate min&max:391.128
# 	time elpased when save normalize [0,1] npy:451.017
# 	time elpased when save normalize [-1,1] npy:494.962
# ====> end to process ../data/brain_henan/algo_mask/brain_seg_by_threshold/1.3.12.2.1107.5.99.2.9594.30000019041407443398400000128/mask_demo0.mha, Time Elapsed:494.963s
