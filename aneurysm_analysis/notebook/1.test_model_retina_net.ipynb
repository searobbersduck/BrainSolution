# %%
import os
import sys
sys.path.append('../')
sys.path.append('../external_lib/medicaldetectiontoolkit')
import utils.model_utils as mutils 
import utils.exp_utils as utils

# %%
conv = mutils.NDConvGenerator(3)

# %%
log_dir = './logs'
os.makedirs(log_dir, exist_ok=True)
logger = utils.get_logger(log_dir)
# Out:
# Logging to ./logs/exec.log

# %%
backbone = utils.import_module('bbone', '../external_lib/medicaldetectiontoolkit/models/backbone.py')

# %%
import importlib.util

# %%
# ?importlib.util.spec_from_file_location

# %%
spec = importlib.util.spec_from_file_location('bbone', '../external_lib/medicaldetectiontoolkit/models/backbone.py')
module = importlib.util.module_from_spec(spec)

# %%
spec.loader.exec_module(module)
